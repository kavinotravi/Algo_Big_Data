# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("output.csv")
df.head()
# Out:
#      M   N   K   iter          error   time
# 0  256  16  -1      0     255.025893   30.0
# 1  256  16  16      1  152632.918360   30.0
# 2  256  16  16      2  152632.918360   30.0
# 3  256  16  16      3  152632.918360   30.0
# 4  256  16  16      4  152632.918360   20.0

# %%
df.tail()
# Out:
#          M    N     K   iter        error     time
# 4702  2048  200  1016     17  2228.201993  27110.0
# 4703  2048  200  1016     18  2218.579249  27330.0
# 4704  2048  200  1016     19  2258.961662  27290.0
# 4705  2048  200  1016     20  2226.102278  27300.0
# 4706  4096   64    -1      0  4094.977011    194.0

# %%
df = df.drop(4706, axis = 0)

# %%
df.columns = ["M", "N", "K", "iter", "error", "time"]
df.columns
# Out:
# Index(['M', 'N', 'K', 'iter', 'error', 'time'], dtype='object')

# %%
groups = df.groupby(["M", "N", "K"])

# %%
Mean_values = groups.mean().reset_index()
Mean_values.head()
# Out:
#      M   N   K  iter          error  time
# 0  256  16  -1   0.0     255.025893  30.0
# 1  256  16  16  10.5  967037.294308  28.5
# 2  256  16  28  10.5     558.115540  28.0
# 3  256  16  40  10.5     348.875500  26.5
# 4  256  16  52  10.5     310.620158  28.5

# %%
Mean_values = Mean_values.drop(["iter"], axis = 1)
Mean_values["rho"]= [0]*len(Mean_values)

# %%
Mean_values.head()
# Out:
#      M   N   K          error  time  rho
# 0  256  16  -1     255.025893  30.0    0
# 1  256  16  16  967037.294308  28.5    0
# 2  256  16  28     558.115540  28.0    0
# 3  256  16  40     348.875500  26.5    0
# 4  256  16  52     310.620158  28.5    0

# %%
for i in range(len(Mean_values)):
    if Mean_values.iloc[i, 2]==-1:
        curr = i
    Mean_values.iloc[i, 5] = (1.0*Mean_values.iloc[i, 3]/Mean_values.iloc[curr, 3])-1.0

Mean_values.head(20)
# Out:
#       M   N    K         error  time          rho
# 0   256  16   -1  2.550259e+02  30.0     0.000000
# 1   256  16   16  9.670373e+05  28.5  3790.918079
# 2   256  16   28  5.581155e+02  28.0     1.188466
# 3   256  16   40  3.488755e+02  26.5     0.368000
# 4   256  16   52  3.106202e+02  28.5     0.217995
# 5   256  16   64  2.906563e+02  29.0     0.139713
# 6   256  16   76  2.807558e+02  33.5     0.100891
# 7   256  16   88  2.727784e+02  34.0     0.069610
# 8   256  16  100  2.675403e+02  34.0     0.049071
# 9   256  16  112  2.705932e+02  38.0     0.061042
# 10  256  17   -1  2.549094e+02  30.0     0.000000
# 11  256  17   17  1.211677e+06  21.0  4752.362037
# 12  256  17   29  9.127257e+02  26.0     2.580589
# 13  256  17   41  4.395638e+02  28.5     0.724392
# 14  256  17   53  3.137738e+02  29.0     0.230923
# 15  256  17   65  2.952208e+02  31.0     0.158140
# 16  256  17   77  2.859312e+02  32.5     0.121697
# 17  256  17   89  2.788111e+02  33.0     0.093765
# ...

# %%
Mean_values["M"].unique()
# Out:
# array([ 256,  512, 1024, 2048])

# %%
m = 256
for n in Mean_values[(Mean_values["M"]==m)].iloc[:, 1].unique():
    plt.plot(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 2].values, np.log(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 5].values), label = "N = {}".format(n))
plt.legend()
plt.show()
# Out:
# /home/ravi/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
m = 512
for n in Mean_values[(Mean_values["M"]==m)].iloc[:, 1].unique():
    plt.plot(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 2].values, np.log(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 5].values), label = "N = {}".format(n))
plt.legend()
plt.show()
# Out:
# /home/ravi/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
m = 1024
for n in Mean_values[(Mean_values["M"]==m)].iloc[:, 1].unique():
    plt.plot(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 2].values, np.log(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 5].values), label = "N = {}".format(n))
plt.legend()
plt.show()
# Out:
# /home/ravi/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
m = 2048
for n in Mean_values[(Mean_values["M"]==m)].iloc[:, 1].unique():
    plt.plot(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 2].values, np.log(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 5].values), label = "N = {}".format(n))
plt.legend()
plt.show()
# Out:
# /home/ravi/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
m = 256
for n in Mean_values[(Mean_values["M"]==m)].iloc[:, 1].unique():
    plt.plot(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 2].values, np.log(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 4].values), label = "N = {}".format(n))
plt.legend()
plt.show()

# %%
m = 512
for n in Mean_values[(Mean_values["M"]==m)].iloc[:, 1].unique():
    plt.plot(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 2].values, np.log(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 4].values), label = "N = {}".format(n))
plt.legend()
plt.show()

# %%
m = 1024
for n in Mean_values[(Mean_values["M"]==m)].iloc[:, 1].unique():
    plt.plot(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 2].values, np.log(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 4].values), label = "N = {}".format(n))
plt.legend()
plt.show()

# %%
m = 2048
for n in Mean_values[(Mean_values["M"]==m)].iloc[:, 1].unique():
    plt.plot(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 2].values, np.log(Mean_values[(Mean_values["M"]==m) & (Mean_values["N"]==n)].iloc[:, 4].values), label = "N = {}".format(n))
plt.legend()
plt.show()
